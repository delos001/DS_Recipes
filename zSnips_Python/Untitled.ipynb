# %%
import numpy as np

x = np.array([[1, 2], [3, 4]])

print(np.sum(x))
print(np.sum(x, axis = 0)) # compute sum of columns
print(np.sum(x, axis = 1)) # compute sum of rows
# Out:
# 10
# [4 6]
# [3 7]
